# %%
import sys
# import path
import os

path_to_folder = os.path.join("Users","32mor","OneDrive", "Documents", "IPP M2", "RL","RL")

sys.path.append('C:/Users/32mor/OneDrive/Documents/IPP M2/RL/RL/src/env')
sys.path.append('C:/Users/32mor/OneDrive/Documents/IPP M2/RL/RL/src/policies')
sys.path.append('C:/Users/32mor/OneDrive/Documents/IPP M2/RL/RL/src/optimizers')
sys.path.append('C:/Users/32mor/OneDrive/Documents/IPP M2/RL/RL/src/viz')

# sys.path.append(os.path.join(path_to_folder,"src","env"))
# sys.path.append(os.path.join(path_to_folder,"src","policies"))
# sys.path.append(os.path.join(path_to_folder,"src","optimizers"))
# sys.path.append(os.path.join(path_to_folder,"src","viz"))
from environment import Environment
from neural_policy import NeuralNetPolicy
from A2C import A2C
from pgo import PGO
from ppo import PPO
import visualization as viz
import pandas as pd

# %%
environment = Environment(Environment.CART_POL_V1, seed=0)
policy = NeuralNetPolicy(environment=environment, hidden_layer_size=256, learning_rate=0.003)
horizon = 500

pgo = PGO(policy=policy, horizon=horizon, gamma=0.99)
pgo_scores = pgo.train(max_trajectory=500, printEvery=50)
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-f44f7129523b> in <module>
# ----> 1 environment = Environment(Environment.CART_POL_V1, seed=0)
#       2 policy = NeuralNetPolicy(environment=environment, hidden_layer_size=256, learning_rate=0.003)
#       3 horizon = 500
#       4
#       5 pgo = PGO(policy=policy, horizon=horizon, gamma=0.99)
#
# C:/Users/lilia/OneDrive/Documents/GitHub/RL/src/env\environment.py in __init__(self, env_id, seed)
#      18     ):
#      19         print(gym.envs.registry)
# ---> 20         if env_id not in gym.envs.registry.keys():
#      21             raise Exception(
#      22                 f"{env_id} is not a registered environment in gym. \nAvailable environments: \n{list(gym.envs.registry.keys())}")
#
# AttributeError: 'EnvRegistry' object has no attribute 'keys'

# %%
a2c = A2C(environment = environment, learning_rate = 0.003, horizon = 500)

a2c_scores = a2c.train_test()
# Out:
# Training :  0
#          * Score :  40
# C:\Users/32mor/OneDrive/Documents/IPP M2/RL/RL/src/optimizers\A2C.py:132: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:233.)
#   s = Variable(torch.FloatTensor(states))
# Training :  50
#          * Score :  21
# Training :  100
#          * Score :  15
# Training :  150
#          * Score :  15
# Training :  200
#          * Score :  16
# Not Training :  250
#          * Score :  225
# Training :  300
#          * Score :  165
# Not Training :  350
#          * Score :  333
# Not Training :  400
#          * Score :  215
# Not Training :  450
#          * Score :  277

# %%
df_scores = pd.DataFrame(data = a2c_scores, columns = ['A2C_scores'])
df_scores['PGO_scores'] = pgo_scores

viz.score_visualisation(df_scores)

# %%
environment = Environment(Environment.CART_POL_V1, seed=0)
trpo = TRPO(environment = environment, learning_rate=0.003, horizon=500, actor_hidden = 64, critic_hidden= 64)

trpo_score = trpo.train()
# Out:
# {'CartPole-v0': EnvSpec(id='CartPole-v0', entry_point='gym.envs.classic_control.cartpole:CartPoleEnv', reward_threshold=195.0, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPole', version=0), 'CartPole-v1': EnvSpec(id='CartPole-v1', entry_point='gym.envs.classic_control.cartpole:CartPoleEnv', reward_threshold=475.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPole', version=1), 'MountainCar-v0': EnvSpec(id='MountainCar-v0', entry_point='gym.envs.classic_control.mountain_car:MountainCarEnv', reward_threshold=-110.0, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='MountainCar', version=0), 'Mountai
# ...

# %%
from collections import namedtuple

rollout = namedtuple('Rollout', ['states', 'actions', 'rewards', 'next_states', ])

# %%
rollout(4 , 2, 4, 4).states
# Out:
# 4

# %%
# Out:
# __main__.Rollout

# %%
import gym

gym.make('CartPole-v1')
# Out:
# <TimeLimit<CartPoleEnv<CartPole-v1>>>
